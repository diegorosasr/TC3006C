# %% [markdown]
# #Pruebas de hipótesis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats

# %%
df=pd.read_excel("/content/Tiempo_clientes.xlsx")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Número de cliente  Tiempo llegada
# 0                    1        1.637848
# 1                    2        1.416632
# 2                    3        0.011483
# 3                    4        1.191507
# 4                    5        0.640180
# ..                 ...             ...
# 623                624        0.753263
# 624                625        1.029053
# 625                626        0.320660
# 626                627        0.887557
# 627                628        4.004106
#
# [628 rows x 2 columns]>

# %%
pd.isna(df).sum()
# Out:
# Número de cliente    0
# Tiempo llegada       0
# dtype: int64

# %%
figura=sm.qqplot(df["Tiempo llegada"],stats.expon,line="45")
